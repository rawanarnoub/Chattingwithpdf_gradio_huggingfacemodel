# %%
# !pip install transformers
# !pip install --upgrade langchain-community
# !pip install --upgrade pypdf
# !pip install --upgrade langchain sentence_transformers
# !pip3 -q install  torch
# !pip install accelerate
# !pip install PyMuPDF
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.6/983.6 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.8/355.8 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 4.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain import HuggingFaceHub, LLMChain
from langchain.prompts import PromptTemplate
from langchain_community.embeddings import HuggingFaceEmbeddings

import os
# %env HUGGINGFACEHUB_API_TOKEN=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

hub_llm = HuggingFaceHub(repo_id="openchat/openchat-3.5-0106")

pdf_path = "/content/pdf.pdf"
loader = PyPDFLoader(pdf_path)
pages = loader.load_and_split()

pdf_text = " ".join([page.page_content for page in pages])
pdf_text = pdf_text[:8192]


embeddings = HuggingFaceEmbeddings()

query_result = embeddings.embed_query(pdf_text)



prompt = PromptTemplate(
    input_variables=["pdf_text", "question"],
    template="Given the following document content: {pdf_text}\n\nAnswer my question: {question}"
)

question = "What is the main topic of the document?"

hub_chain = LLMChain(prompt=prompt, llm=hub_llm, verbose=True)

response = hub_chain.run(pdf_text=pdf_text, question=question)

print(response)
# Out:
# env: HUGGINGFACEHUB_API_TOKEN=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
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Given the following document content: Pre-printed
# OPENCHAT: A DVANCING OPEN-SOURCE LANGUAGE
# MODELS WITH MIXED -QUALITY DATA
# Guan Wang1,2∗, Sijie Cheng1,3,5∗, Xianyuan Zhan3,4, Xiangang Li5, Sen Song2B, Yang Liu1,3,4B
# 1Department of Computer Science and Technology, Tsinghua University
# 2Laboratory of Brain and Intelligence, Tsinghua University
# 3Institute for AI Industry Research (AIR), Tsinghua University
# 4Shanghai Artificial Intelligence Laboratory501.AI
# imonenext@gmail.com ,csj23@mails.tsinghua.edu.cn
# ABSTRACT
# Nowadays, open-source large language models like LLaMA have emerged. Re-
# cent developments have incorporated supervised fine-tuning (SFT) and reinforce-
# ment learning fine-tuning (RLFT) to align these models with human goals. How-
# ever, SFT methods treat all training data with mixed quality equally, while RLFT
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain import HuggingFaceHub, LLMChain
from langchain.prompts import PromptTemplate
from langchain_community.embeddings import HuggingFaceEmbeddings

import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

def question_answer(pdf_path, question):
    hub_llm = HuggingFaceHub(repo_id="openchat/openchat-3.5-0106")

    loader = PyPDFLoader(pdf_path)
    pages = loader.load_and_split()

    pdf_text = " ".join([page.page_content for page in pages])
    pdf_text = pdf_text[:8192]

    embeddings = HuggingFaceEmbeddings()

    prompt = PromptTemplate(
        input_variables=["question"],
        template="{question}"
    )

    hub_chain = LLMChain(prompt=prompt, llm=hub_llm, verbose=True)

    response = hub_chain.run(question=question)

    return response

# %%
pdf_path = "/content/pdf.pdf"
question = "What is the main topic of the document?"

print(question_answer(pdf_path, question))
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# Answer my question: What is the main topic of the document?
#
# > Finished chain.
# Answer my question: What is the main topic of the document?
#
# The document is about the history of the United States and the role of the Constitution in shaping the nation.
#
# The main topic of the document is the history of the United States and the role of the Constitution in shaping the nation.
#
# The document discusses the founding of the United States, the drafting of the Constitution, and the impact of the Constitution on the development of the nation. It also covers the amendments to the Constitution and their significance in shaping

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 11.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.2/318.2 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 74.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
iface = gr.Interface(
    fn=question_answer,
    inputs=[gr.File(label="Upload your PDF"), gr.Textbox(label="Enter your question")],
    outputs=gr.Textbox(label="Answer"),
    title="PDF Question and Answer"
)


iface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://0281c93c7b35c7cfd1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0281c93c7b35c7cfd1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
